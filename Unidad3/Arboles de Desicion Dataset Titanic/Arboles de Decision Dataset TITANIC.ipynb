# %% [markdown]
# ![](TN-comunidades-Instituto-Tecnologico-de-Durango.png)
#
#
# # Inteligencia Artificial
# ## Arboles de Decision Dataset TITANIC
#
# ## Nombre del docente
# ### Jose Gabriel Rodriguez Rivas
#
# ## Nombre del alumno
# ### Oswaldo Zura Alvarado

# %% [markdown]
# ### Aspectos básicos/situación
# En esta práctica de laboratorio creará un clasificador de árbol de decisiones que funcione con un conjunto de datos que contenga detalles sobre los más de 1300 pasajeros que estaban a bordo del trasatlántico Titanic durante su trágico primer viaje.

# %% [markdown]
# **Con los datos de arriba, ¿qué tipos de preguntas podemos hacer acerca de los factores que contribuyeron a que los pasajeros sobrevivan o fallecieran en la catástrofe del Titanic?**
#
# **Respuesta**Por ejemplo ¿en que clase hiban los pasajeron?, ¿cuanto pagaron por el boleto?, ¿que edad tenian?

# %%
#import pandas
import pandas as pd

#create a pandas dataframe called "training" from the titanic-train.csv file
training = pd.read_csv("titanic-train.csv")

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton    male  31.0
# 1            2         0       3              Asim, Mr. Adola    male  35.0
# 2            3         0       3           Nankoff, Mr. Minko    male   NaN
# 3            4         0       1     Thayer, Mr. John Borland    male  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia  female  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
#Code cell 2
#verify the contents of the training dataframe using the pandas info() method.
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  915 non-null    int64
#  1   Survived     915 non-null    int64
#  2   Pclass       915 non-null    int64
#  3   Name         915 non-null    object
#  4   Gender       915 non-null    object
#  5   Age          738 non-null    float64
#  6   SibSp        915 non-null    int64
#  7   Parch        915 non-null    int64
#  8   Ticket       915 non-null    object
#  9   Fare         915 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     914 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 85.9+ KB

# %% [markdown]
# **¿Faltan valores en el conjunto de datos?**
#
# **Respuesta** Hay datos nulos en algunas columnas

# %% [markdown]
# ### Paso 2: Preparar los datos para el modelo de árbol de decisiones

# %%
training["Gender"] = training["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton       0  31.0
# 1            2         0       3              Asim, Mr. Adola       0  35.0
# 2            3         0       3           Nankoff, Mr. Minko       0   NaN
# 3            4         0       1     Thayer, Mr. John Borland       0  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia       1  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
training["Age"].fillna(training["Age"].mean(), inplace=True)

# %%
training
# Out:
#      PassengerId  Survived  Pclass                         Name  Gender  \
# 0              1         0       1       Davidson, Mr. Thornton       0
# 1              2         0       3              Asim, Mr. Adola       0
# 2              3         0       3           Nankoff, Mr. Minko       0
# 3              4         0       1     Thayer, Mr. John Borland       0
# 4              5         0       3  Strandberg, Miss. Ida Sofia       1
# ..           ...       ...     ...                          ...     ...
# 910          911         0       3          Baccos, Mr. Raffull       0
# 911          912         0       1   Smith, Mr. Richard William       0
# 912          913         0       3             Wirz, Mr. Albert       0
# 913          914         0       3          Johnson, Mr. Alfred       0
# 914          915         0       3             Fox, Mr. Patrick       0
#
#            Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0    31.000000      1      0          F.C. 12750   52.0000   B71        S
# 1    35.000000      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2    29.970867      0      0              349218    7.8958   NaN        S
# 3    49.000000      1      1               17421  110.8833   C68        C
# 4    22.000000      0      0                7553    9.8375   NaN        S
# ..         ...    ...    ...                 ...       ...   ...      ...
# 910  20.000000      0      0                2679    7.2250   NaN        C
# 911  29.970867      0      0              113056   26.0000   A19        S
# 912  27.000000      0      0              315154    8.6625   NaN        S
# 913  49.000000      0      0                LINE    0.0000   NaN        S
# 914  29.970867      0      0              368573    7.7500   NaN        Q
#
# [915 rows x 12 columns]

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  915 non-null    int64
#  1   Survived     915 non-null    int64
#  2   Pclass       915 non-null    int64
#  3   Name         915 non-null    object
#  4   Gender       915 non-null    int64
#  5   Age          915 non-null    float64
#  6   SibSp        915 non-null    int64
#  7   Parch        915 non-null    int64
#  8   Ticket       915 non-null    object
#  9   Fare         915 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     914 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 85.9+ KB

# %% [markdown]
# **¿Cuál es el valor que se utilizó para reemplazar a las edades faltantes?**
#
# **Respuesta**: 29.970867

# %% [markdown]
# ### Paso 3: Entrenar y calificar el modelo del árbol de decisiones.

# %%
#create the array for the target values
y_target = training["Survived"].values

# %%
columns = ["Fare", "Pclass", "Gender", "Age", "SibSp"]
#create the variable to hold the features that the classifier will use
X_input = training[list(columns)].values

# %%
#import the tree module from the sklearn library
from sklearn import tree

#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#train the model using the fit() method of the decision tree object. 
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %% [markdown]
# #### Evalúe el modelo.
# Utilice el método score() del objeto del árbol de decisiones para mostrar la precisión del porcentaje de las asignaciones realizadas por el clasificador. Este método considera las variables de entrada y salida como argumentos.

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.8163934426229508

# %% [markdown]
# ### Paso 6: Visualizar el árbol

# %%
clasificacion = ['NO SOBREVIVE', 'SOBREVIVE']

# %%
from sklearn.externals.six import StringIO
with open("titanic.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns,
                           class_names =clasificacion)
# Out:
# C:\Users\oswal\anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
#run the Graphviz dot command to convert the .dot file to .png
# !dot -Tpng titanic.dot -o titanic.png

# %%
#import the Image module from the Ipython.display libary
from IPython.display import Image

#display the decison tree graphic
Image("titanic.png")

# %%
import graphviz
dot_data=tree.export_graphviz(clf_train, out_file=None,
                              class_names =clasificacion,
                             feature_names =columns,
                             filled=True, rounded=True,
                             special_characters=True)
graph = graphviz.Source(dot_data)
graph.render("TITANICCOLOR", format='png')
graph

# %% [markdown]
# **¿Qué describe al grupo que tenía mayor cantidad de víctimas fatales? ¿Qué grupo tenía la mayor cantidad de sobrevivientes?**
#
# **Respuesta** El grupo que tiene el mayor numero de victimas fatales se encuentra en la rama de hombres que viajaban en primera clase y con edades menores a 14 y el grupo que tenia el mayor numero de sobrevivientes se encuentra en la rama de las mujeres en el grupo de primera o segunda clase

# %% [markdown]
# ### Parte 2: Aplicar el modelo del árbol de decisiones

# %%
#import the file into the 'testing' dataframe.
testing = pd.read_csv("titanic-test.csv")
testing
# Out:
#      PassengerId  Survived  Pclass  \
# 0            916         0       2
# 1            917         1       1
# 2            918         0       3
# 3            919         1       1
# 4            920         1       3
# ..           ...       ...     ...
# 388         1304         0       3
# 389         1305         0       3
# 390         1306         1       1
# 391         1307         0       3
# 392         1308         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                      Coleridge, Mr. Reginald Charles    male  29.0      0
# 1    Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 2                                  Windelov, Mr. Einar    male  21.0      0
# 3                               Minahan, Miss. Daisy E  female  33.0      1
# 4                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ..                                                 ...     ...   ...    ...
# 388                              Thomas, Mr. Charles P    male   NaN      1
# 389                                Paulner, Mr. Uscher    male   NaN      0
# 390                     Thorne, Mrs. Gertrude Maybelle  female   NaN      0
# 391                          Holthen, Mr. Johan Martin    male  28.0      0
# 392               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
#
#      Parch            Ticket      Fare Cabin Embarked
# 0        0       W./C. 14263   10.5000   NaN        S
# 1        1             16966  134.5000   E34        C
# 2        0  SOTON/OQ 3101317    7.2500   NaN        S
# 3        0             19928   90.0000   C78        Q
# 4        0            363272    7.0000   NaN        S
# ..     ...               ...       ...   ...      ...
# 388      0              2621    6.4375   NaN        C
# 389      0              3411    8.7125   NaN        C
# 390      0          PC 17585   79.2000   NaN        C
# 391      0            C 4001   22.5250   NaN        S
# 392      0             27042   30.0000   A23        S
#
# [393 rows x 12 columns]

# %% [markdown]
# **¿Cuántos registros hay en el conjunto de datos?**
#
# 393
#
# **¿Qué variable(s) importante(s) son valores faltantes y cuántas faltan?**
#
# Al parecer no falta ninguna variable

# %%
#replace the Gender labels in the testing dataframe
testing["Gender"] = testing["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
#Use the fillna method of the testing dataframe column "Age" 
#to replace missing values with the mean of the age values.
testing["Age"].fillna(testing["Age"].mean(), inplace=True)

# %%
testing.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          916         0       2
# 1          917         1       1
# 2          918         0       3
# 3          919         1       1
# 4          920         1       3
# 5          921         0       3
# 6          922         0       3
# 7          923         0       3
# 8          924         0       3
# 9          925         0       2
#
#                                                 Name  Gender       Age  SibSp  \
# 0                    Coleridge, Mr. Reginald Charles       0  29.00000      0
# 1  Spedden, Mrs. Frederic Oakley (Margaretta Corn...       1  40.00000      1
# 2                                Windelov, Mr. Einar       0  21.00000      0
# 3                             Minahan, Miss. Daisy E       1  33.00000      1
# 4                   Wilkes, Mrs. James (Ellen Needs)       1  47.00000      1
# 5                        Abbott, Mr. Rossmore Edward       0  16.00000      1
# 6                          Karlsson, Mr. Nils August       0  22.00000      0
# 7                            Connaghton, Mr. Michael       0  31.00000      0
# 8                                 Foley, Mr. William       0  29.56569      0
# 9                  Leyson, Mr. Robert William Norman       0  24.00000      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0       W./C. 14263   10.5000   NaN        S
# 1      1             16966  134.5000   E34        C
# 2      0  SOTON/OQ 3101317    7.2500   NaN        S
# 3      0             19928   90.0000   C78        Q
# 4      0            363272    7.0000   NaN        S
# 5      1         C.A. 2673   20.2500   NaN        S
# 6      0            350060    7.5208   NaN        S
# 7      0            335097    7.7500   NaN        Q
# 8      0            365235    7.7500   NaN        Q
# 9      0        C.A. 29566   10.5000   NaN        S

# %%
X_input = testing[list(columns)].values

# %% [markdown]
# #### Hacer predicciones con el metodo predict del clasificador
# Utilice el método predict() del objeto clf_train que se entrenó para etiquetar las observaciones en el conjunto de datos de prueba con la clasificación de supervivencia más probable. Considere el arreglo de variables de entrada del conjunto de datos de prueba como el parámetro para este método.

# %%
target_labels = clf_train.predict(X_input)

#convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argument
target_labels = pd.DataFrame({'Est_Survival':target_labels, 'Name':testing['Name']})

# %%
target_labels.head()
# Out:
#    Est_Survival                                               Name
# 0             0                    Coleridge, Mr. Reginald Charles
# 1             1  Spedden, Mrs. Frederic Oakley (Margaretta Corn...
# 2             0                                Windelov, Mr. Einar
# 3             1                             Minahan, Miss. Daisy E
# 4             0                   Wilkes, Mrs. James (Ellen Needs)

# %%
#import the numpy library as np
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("titanic_all.csv")
# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])

# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))
# Print the result
acc
# Out:
# 0.7588832487309645

# %% [markdown]
# ### Parte 3: Evaluar el modelo del árbol de decisiones

# %%
#import the titanic_all.csv file into a dataframe called all_data. Specify the list of columns to import.
all_data = pd.read_csv("titanic_all.csv", usecols=['Survived','Pclass','Gender','Age','SibSp','Fare'])
#View info for the new dataframe
all_data
# Out:
#       Survived  Pclass  Gender      Age  SibSp      Fare
# 0            1       1  female  29.0000      0  211.3375
# 1            1       1    male   0.9167      1  151.5500
# 2            0       1  female   2.0000      1  151.5500
# 3            0       1    male  30.0000      1  151.5500
# 4            0       1  female  25.0000      1  151.5500
# ...        ...     ...     ...      ...    ...       ...
# 1303         0       3  female  14.5000      1   14.4542
# 1304         0       3  female      NaN      1   14.4542
# 1305         0       3    male  26.5000      0    7.2250
# 1306         0       3    male  27.0000      0    7.2250
# 1307         0       3    male  29.0000      0    7.8750
#
# [1308 rows x 6 columns]

# %% [markdown]
# **¿Cuántos registros hay en el conjunto de datos?**
#
# 1308
#
# **¿Qué variable(s) importante(s) son valores faltantes y cuántas faltan?**
#
# Salen las columnas que se mandaron a llamar

# %%
all_data["Gender"] = all_data["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
all_data["Age"].fillna(all_data["Age"].mean(), inplace=True)

# %%
all_data.head(10)
# Out:
#    Survived  Pclass  Gender      Age  SibSp      Fare
# 0         1       1       1  29.0000      0  211.3375
# 1         1       1       0   0.9167      1  151.5500
# 2         0       1       1   2.0000      1  151.5500
# 3         0       1       0  30.0000      1  151.5500
# 4         0       1       1  25.0000      1  151.5500
# 5         1       1       0  48.0000      0   26.5500
# 6         1       1       1  63.0000      1   77.9583
# 7         0       1       0  39.0000      0    0.0000
# 8         1       1       1  53.0000      2   51.4792
# 9         0       1       0  71.0000      0   49.5042

# %%
#Import train_test_split() from the sklearn.model_selection libary 
from sklearn.model_selection import train_test_split

#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
X = all_data[list(columns)].values
y = all_data["Survived"].values

#generate the four testing and training data arrays with the train_test_split() method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
#create the training decision tree object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %%
#score the model on the two datasets and store the scores in variables. Convert the scores to strings using str()
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8201530612244898 Testing score = 0.8053435114503816

# %% [markdown]
# ## Tarea
# **1. Eliminar las observaciones con valores de edad faltantes**
#
# El uso de un promedio para reemplazar los valores de edad faltantes puede afectar la precisión del modelo. Una solución para esto puede ser eliminar todas las observaciones con valores de edad faltantes. Si bien esto reducirá el tamaño del conjunto de datos de entrenamiento, podría mejorar la precisión.

# %%
training = pd.read_csv("titanic-train.csv")
training["Gender"] = training["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton       0  31.0
# 1            2         0       3              Asim, Mr. Adola       0  35.0
# 2            3         0       3           Nankoff, Mr. Minko       0   NaN
# 3            4         0       1     Thayer, Mr. John Borland       0  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia       1  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
training.dropna(subset=['Age'], inplace=True)
training
# Out:
#      PassengerId  Survived  Pclass                           Name  Gender  \
# 0              1         0       1         Davidson, Mr. Thornton       0
# 1              2         0       3                Asim, Mr. Adola       0
# 3              4         0       1       Thayer, Mr. John Borland       0
# 4              5         0       3    Strandberg, Miss. Ida Sofia       1
# 5              6         0       2           Bowenur, Mr. Solomon       0
# ..           ...       ...     ...                            ...     ...
# 907          908         0       2  Fillbrook, Mr. Joseph Charles       0
# 909          910         0       3       Crease, Mr. Ernest James       0
# 910          911         0       3            Baccos, Mr. Raffull       0
# 912          913         0       3               Wirz, Mr. Albert       0
# 913          914         0       3            Johnson, Mr. Alfred       0
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0    31.0      1      0          F.C. 12750   52.0000   B71        S
# 1    35.0      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 3    49.0      1      1               17421  110.8833   C68        C
# 4    22.0      0      0                7553    9.8375   NaN        S
# 5    42.0      0      0              211535   13.0000   NaN        S
# ..    ...    ...    ...                 ...       ...   ...      ...
# 907  18.0      0      0          C.A. 15185   10.5000   NaN        S
# 909  19.0      0      0           S.P. 3464    8.1583   NaN        S
# 910  20.0      0      0                2679    7.2250   NaN        C
# 912  27.0      0      0              315154    8.6625   NaN        S
# 913  49.0      0      0                LINE    0.0000   NaN        S
#
# [738 rows x 12 columns]

# %%
y_target = training["Survived"].values

# %%
columns = ["Fare", "Pclass", "Gender", "Age", "SibSp"]
X_input = training[list(columns)].values

# %%
from sklearn import tree
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf_train = clf_train.fit(X_input, y_target)

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.8252032520325203

# %%
clasificacion=['No Sobrevive', 'Sobrevive']

# %%
from sklearn.externals.six import StringIO
with open("titanicc.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns,
                           class_names =clasificacion)

# %%
# !dot -Tpng titanicc.dot -o titanicc.png

# %%
from IPython.display import Image
Image("titanicc.png")

# %%
import graphviz
dot_data=tree.export_graphviz(clf_train, out_file=None,
                              class_names =clasificacion,
                             feature_names =columns,
                             filled=True, rounded=True,
                             special_characters=True)
graph = graphviz.Source(dot_data)
graph.render("TITANICCOLORr", format='png')
graph

# %% [markdown]
# **Reflexion: que diferencias se obtuvieron al ejecutar el entrenamiento,eliminando los valores nulos de la edad.**
# Hay mejor precision en los datos, ya que al momento de borrar los valores nulos se analisan menos datos, cambiando algunos datos que el mas notoria es la edad que de estar en 14 ahora se puede observar en 9.5, se logra tener un analisis mas rapido y mas preciso
#
# **Porcentaje**
# Con ayuda del metodo score(), se puede apreciar que se logra una precision aproximada del 82%
#
# **Conclusion**
# El tema de los arboles es muy importante y se puede utilizar praticamente para cualquier tipo de situacion en donde se requiera una tomar una decision rapida y presisa, ya que ademas de darte una respuesta rapida es justificada, en esta practica se pudo observar por ejemplo si la edad era un valor importante, tambien si afecto el que los pasajeros tomaran primera, segunda o tercera clase ya que basados en estos datos o valores se pudo llegar a una conclusion de quienes sobrevivieron o no.
